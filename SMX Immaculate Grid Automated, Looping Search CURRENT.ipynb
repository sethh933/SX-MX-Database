# %%
import random
import pyodbc

# Define templates for different types of queries, including the new Lites class champion template
query_templates = {
    'brand_country': """
        SELECT rbl.FullName 
        FROM RiderBrandList rbl 
        JOIN Rider_List rl ON rbl.RiderID = rl.RiderID 
        WHERE rbl.Brand = '{brand}' 
          AND rl.Country = '{country}'
    """,
    'brand_achievement': """
        SELECT r.FullName 
        FROM RiderBrandList b 
        JOIN Class1_Wins_Leaderboard s ON b.RiderID = s.RiderID 
        JOIN Rider_List r ON b.RiderID = r.RiderID 
        WHERE b.Brand = '{brand}' 
          AND s.SX_MAINS_Wins >= {wins}
    """,
    'champion_country': """
        SELECT r.FullName 
        FROM Champions c 
        JOIN Rider_List r ON c.RiderID = r.RiderID 
        WHERE c.SportID = 1 
          AND c.ClassID = 1 
          AND r.Country = '{country}'
    """,
    'champion_achievement': """
        SELECT r.FullName 
        FROM Champions c 
        JOIN Rider_List r ON c.RiderID = r.RiderID 
        JOIN Class1_Wins_Leaderboard s ON r.RiderID = s.RiderID 
        WHERE c.SportID = 1 
          AND c.ClassID = 1 
          AND s.SX_MAINS_Wins >= {wins}
    """,
    'lites_champion_country': """
        SELECT r.FullName 
        FROM Champions c 
        JOIN Rider_List r ON c.RiderID = r.RiderID 
        WHERE c.SportID = 1 
          AND c.ClassID = 2 
          AND r.Country = '{country}'
    """,
    'lites_champion_achievement': """
        SELECT r.FullName 
        FROM Champions c 
        JOIN Rider_List r ON c.RiderID = r.RiderID 
        JOIN Class2_Wins_Leaderboard s ON r.RiderID = s.RiderID 
        WHERE c.SportID = 1 
          AND c.ClassID = 2 
          AND s.SX_MAINS_Wins >= {wins}
    """,
    'mxchampion_country': """
        SELECT r.FullName 
        FROM Champions c 
        JOIN Rider_List r ON c.RiderID = r.RiderID 
        WHERE c.SportID = 2 
          AND c.ClassID = 1 
          AND r.Country = '{country}'
    """,
    'brand_mxachievement': """
        SELECT r.FullName 
        FROM RiderBrandList b 
        JOIN Class1_Wins_Leaderboard s ON b.RiderID = s.RiderID 
        JOIN Rider_List r ON b.RiderID = r.RiderID 
        WHERE b.Brand = '{brand}' 
          AND s.MX_OVERALLS_Wins >= {wins}
    """,
    'brand_mx2achievement': """
        SELECT r.FullName 
        FROM RiderBrandList b 
        JOIN Class2_Wins_Leaderboard s ON b.RiderID = s.RiderID 
        JOIN Rider_List r ON b.RiderID = r.RiderID 
        WHERE b.Brand = '{brand}' 
          AND s.MX_OVERALLS_Wins >= {wins}
    """
}

# Define lists of values for brands, countries, and achievements
brands = ['KAW', 'YAM', 'KTM', 'HON', 'SUZ', 'GAS', 'HUS']
countries = ['United States', 'Australia', 'France', 'South Africa']
achievements = [10, 20, 5, 1]  # Representing win counts

# Define the function for generating queries
def generate_query(template_key, **params):
    template = query_templates.get(template_key)
    if not template:
        raise ValueError(f"No template found for key: {template_key}")
    return template.format(**params)

# Function to generate queries automatically
def generate_queries():
    queries = {}
    
    # Generate brand-country queries
    for brand in brands:
        for country in countries:
            query_key = f"{brand}-{country}"
            queries[query_key] = generate_query('brand_country', brand=brand, country=country)
    
    # Generate brand-achievement queries
    for brand in brands:
        for wins in achievements:
            query_key = f"{brand}-{wins}+ Premier Class Wins"
            queries[query_key] = generate_query('brand_achievement', brand=brand, wins=wins)
    
    # Generate premier champion-country queries
    for country in countries:
        query_key = f"Premier Class SX Champion-{country}"
        queries[query_key] = generate_query('champion_country', country=country)
    
    # Generate premier champion-achievement queries
    for wins in achievements:
        query_key = f"Premier Class SX Champion-{wins}+ Premier Class Wins"
        queries[query_key] = generate_query('champion_achievement', wins=wins)
    
    # Generate lites champion-country queries
    for country in countries:
        query_key = f"Lites Class SX Champion-{country}"
        queries[query_key] = generate_query('lites_champion_country', country=country)
    
    # Generate lites champion-achievement queries
    for wins in achievements:
        query_key = f"Lites Class SX Champion-{wins}+ Lites Class Wins"
        queries[query_key] = generate_query('lites_champion_achievement', wins=wins)
    
    # Generate 450 MX champion-country queries
    for country in countries:
        query_key = f"450 MX Champion-{country}"
        queries[query_key] = generate_query('mxchampion_country', country=country)
    
    # Generate brand-MX achievement queries for 450 class
    for brand in brands:
        for wins in achievements:
            query_key = f"{brand}-{wins}+ 450 MX Wins"
            queries[query_key] = generate_query('brand_mxachievement', brand=brand, wins=wins)
    
    # Generate brand-MX achievement queries for 250 class
    for brand in brands:
        for wins in achievements:
            query_key = f"{brand}-{wins}+ 250 MX Wins"
            queries[query_key] = generate_query('brand_mx2achievement', brand=brand, wins=wins)
    
    return queries

# Example usage to automatically generate all queries
all_queries = generate_queries()
print("Generated Queries:")
for key, query in all_queries.items():
    print(f"{key}:\n{query}\n")
# Out:
# Generated Queries:
# KAW-United States:
#
#         SELECT rbl.FullName
#         FROM RiderBrandList rbl
#         JOIN Rider_List rl ON rbl.RiderID = rl.RiderID
#         WHERE rbl.Brand = 'KAW'
#           AND rl.Country = 'United States'
#
#
# KAW-Australia:
#
#         SELECT rbl.FullName
#         FROM RiderBrandList rbl
#         JOIN Rider_List rl ON rbl.RiderID = rl.RiderID
#         WHERE rbl.Brand = 'KAW'
#           AND rl.Country = 'Australia'
#
#
# KAW-France:
#
#         SELECT rbl.FullName
#         FROM RiderBrandList rbl
#         JOIN Rider_List rl ON rbl.RiderID = rl.RiderID
#         WHERE rbl.Brand = 'KAW'
#           AND rl.Country = 'France'
#
#
# KAW-South Africa:
#
#         SELECT rbl.FullName
#         FROM RiderBrandList rbl
#         JOIN Rider_List rl ON rbl.RiderID = rl.RiderID
#         WHERE rbl.Brand = 'KAW'
#           AND rl.Country = 'South Africa'
#
#
# YAM-United States:
#
#         SELECT rbl.FullName
#         FROM RiderBrandList rbl
#         JOIN Rider_List rl ON rbl.RiderID = rl.RiderID
#         WHERE rbl.Brand = 'YAM'
#           AND rl.Country = 'United States'
#
#
# YAM-Australia:
#
#         SELECT rbl.FullName
#         FROM RiderBrandList rbl
#         JOIN Rider_List rl ON rbl.RiderID = rl.RiderID
#         WHERE rbl.Brand = 'YAM'
#           AND rl.Country = 'Australia'
#
#
# YAM-France:
#
#         SELECT rbl.FullName
#         FROM RiderBrandList rbl
#         JOIN Rider_List rl ON rbl.RiderID = rl.RiderID
#         WHERE rbl.Brand = 'YAM'
#           AND rl.Country = 'France'
#
#
# YAM-South Africa:
#
#         SELECT rbl.FullName
#         FROM RiderBrandList rbl
#         JOIN Rider_List rl ON rbl.RiderID = rl.RiderID
#         WHERE rbl.Brand = 'YAM'
#           AND rl.Country = 'South Africa'
#
#
# KTM-United States:
#
#         SELECT rbl.FullName
#         FROM RiderBrandList rbl
#         JOIN Rider_List rl ON rbl.RiderID = rl.RiderID
#         WHERE rbl.Brand = 'KTM'
#           AND rl.Country = 'United States'
#
#
# KTM-Australia:
#
#         SELECT rbl.FullName
#         FROM RiderBrandList rbl
#         JOIN Rider_List rl ON rbl.RiderID = rl.RiderID
#         WHERE rbl.Brand = 'KTM'
#           AND rl.Country = 'Australia'
#
#
# KTM-France:
#
#         SELECT rbl.FullName
#         FROM RiderBrandList rbl
#         JOIN Rider_List rl ON rbl.RiderID = rl.RiderID
#         WHERE rbl.Brand = 'KTM'
#           AND rl.Country = 'France'
#
#
# KTM-South Africa:
#
#         SELECT rbl.FullName
#         FROM RiderBrandList rbl
#         JOIN Rider_List rl ON rbl.RiderID = rl.RiderID
#         WHERE rbl.Brand = 'KTM'
#           AND rl.Country = 'South Africa'
#
#
# HON-United States:
#
#         SELECT rbl.FullName
#         FROM RiderBrandList rbl
#         JOIN Rider_List rl ON rbl.RiderID = rl.RiderID
#         WHERE rbl.Brand = 'HON'
#           AND rl.Country = 'United States'
#
#
# HON-Australia:
#
#         SELECT rbl.FullName
#         FROM RiderBrandList rbl
#         JOIN Rider_List rl ON rbl.RiderID = rl.RiderID
#         WHERE rbl.Brand = 'HON'
#           AND rl.Country = 'Australia'
#
#
# HON-France:
#
#         SELECT rbl.FullName
#         FROM RiderBrandList rbl
#         JOIN Rider_List rl ON rbl.RiderID = rl.RiderID
#         WHERE rbl.Brand = 'HON'
#           AND rl.Country = 'France'
#
#
# HON-South Africa:
#
#         SELECT rbl.FullName
#         FROM RiderBrandList rbl
#         JOIN Rider_List rl ON rbl.RiderID = rl.RiderID
#         WHERE rbl.Brand = 'HON'
#           AND rl.Country = 'South Africa'
#
#
# SUZ-United States:
#
#         SELECT rbl.FullName
#         FROM RiderBrandList rbl
#         JOIN Rider_List rl ON rbl.RiderID = rl.RiderID
#         WHERE rbl.Brand = 'SUZ'
#           AND rl.Country = 'United States'
#
#
# SUZ-Australia:
#
#         SELECT rbl.FullName
#         FROM RiderBrandList rbl
#         JOIN Rider_List rl ON rbl.RiderID = rl.RiderID
#         WHERE rbl.Brand = 'SUZ'
#           AND rl.Country = 'Australia'
#
#
# SUZ-France:
#
#         SELECT rbl.FullName
#         FROM RiderBrandList rbl
#         JOIN Rider_List rl ON rbl.RiderID = rl.RiderID
#         WHERE rbl.Brand = 'SUZ'
#           AND rl.Country = 'France'
#
#
# SUZ-South Africa:
#
#         SELECT rbl.FullName
#         FROM RiderBrandList rbl
#         JOIN Rider_List rl ON rbl.RiderID = rl.RiderID
#         WHERE rbl.Brand = 'SUZ'
#           AND rl.Country = 'South Africa'
#
#
# GAS-United States:
#
#         SELECT rbl.FullName
#         FROM RiderBrandList rbl
#         JOIN Rider_List rl ON rbl.RiderID = rl.RiderID
#         WHERE rbl.Brand = 'GAS'
#           AND rl.Country = 'United States'
#
#
# GAS-Australia:
#
#         SELECT rbl.FullName
#         FROM RiderBrandList rbl
#         JOIN Rider_List rl ON rbl.RiderID = rl.RiderID
#         WHERE rbl.Brand = 'GAS'
#           AND rl.Country = 'Australia'
#
#
# GAS-France:
#
#         SELECT rbl.FullName
#         FROM RiderBrandList rbl
#         JOIN Rider_List rl ON rbl.RiderID = rl.RiderID
#         WHERE rbl.Brand = 'GAS'
#           AND rl.Country = 'France'
#
#
# GAS-South Africa:
#
#         SELECT rbl.FullName
#         FROM RiderBrandList rbl
#         JOIN Rider_List rl ON rbl.RiderID = rl.RiderID
#         WHERE rbl.Brand = 'GAS'
#           AND rl.Country = 'South Africa'
#
#
# HUS-United States:
#
#         SELECT rbl.FullName
#         FROM RiderBrandList rbl
#         JOIN Rider_List rl ON rbl.RiderID = rl.RiderID
#         WHERE rbl.Brand = 'HUS'
#           AND rl.Country = 'United States'
#
#
# HUS-Australia:
#
#         SELECT rbl.FullName
#         FROM RiderBrandList rbl
#         JOIN Rider_List rl ON rbl.RiderID = rl.RiderID
#         WHERE rbl.Brand = 'HUS'
#           AND rl.Country = 'Australia'
#
#
# HUS-France:
#
#         SELECT rbl.FullName
#         FROM RiderBrandList rbl
#         JOIN Rider_List rl ON rbl.RiderID = rl.RiderID
#         WHERE rbl.Brand = 'HUS'
#           AND rl.Country = 'France'
#
#
# HUS-South Africa:
#
#         SELECT rbl.FullName
#         FROM RiderBrandList rbl
#         JOIN Rider_List rl ON rbl.RiderID = rl.RiderID
#         WHERE rbl.Brand = 'HUS'
#           AND rl.Country = 'South Africa'
#
#
# KAW-10+ Premier Class Wins:
#
#         SELECT r.FullName
#         FROM RiderBrandList b
#         JOIN Class1_Wins_Leaderboard s ON b.RiderID = s.RiderID
#         JOIN Rider_List r ON b.RiderID = r.RiderID
#         WHERE b.Brand = 'KAW'
#           AND s.SX_MAINS_Wins >= 10
#
#
# KAW-20+ Premier Class Wins:
#
#         SELECT r.FullName
#         FROM RiderBrandList b
#         JOIN Class1_Wins_Leaderboard s ON b.RiderID = s.RiderID
#         JOIN Rider_List r ON b.RiderID = r.RiderID
#         WHERE b.Brand = 'KAW'
#           AND s.SX_MAINS_Wins >= 20
#
#
# KAW-5+ Premier Class Wins:
#
#         SELECT r.FullName
#         FROM RiderBrandList b
#         JOIN Class1_Wins_Leaderboard s ON b.RiderID = s.RiderID
#         JOIN Rider_List r ON b.RiderID = r.RiderID
#         WHERE b.Brand = 'KAW'
#           AND s.SX_MAINS_Wins >= 5
#
#
# KAW-1+ Premier Class Wins:
#
#         SELECT r.FullName
#         FROM RiderBrandList b
#         JOIN Class1_Wins_Leaderboard s ON b.RiderID = s.RiderID
#         JOIN Rider_List r ON b.RiderID = r.RiderID
#         WHERE b.Brand = 'KAW'
#           AND s.SX_MAINS_Wins >= 1
#
#
# YAM-10+ Premier Class Wins:
#
#         SELECT r.FullName
#         FROM RiderBrandList b
#         JOIN Class1_Wins_Leaderboard s ON b.RiderID = s.RiderID
#         JOIN Rider_List r ON b.RiderID = r.RiderID
#         WHERE b.Brand = 'YAM'
#           AND s.SX_MAINS_Wins >= 10
#
#
# YAM-20+ Premier Class Wins:
#
#         SELECT r.FullName
#         FROM RiderBrandList b
#         JOIN Class1_Wins_Leaderboard s ON b.RiderID = s.RiderID
#         JOIN Rider_List r ON b.RiderID = r.RiderID
#         WHERE b.Brand = 'YAM'
#           AND s.SX_MAINS_Wins >= 20
#
#
# YAM-5+ Premier Class Wins:
#
#         SELECT r.FullName
#         FROM RiderBrandList b
#         JOIN Class1_Wins_Leaderboard s ON b.RiderID = s.RiderID
#         JOIN Rider_List r ON b.RiderID = r.RiderID
#         WHERE b.Brand = 'YAM'
#           AND s.SX_MAINS_Wins >= 5
#
#
# YAM-1+ Premier Class Wins:
#
#         SELECT r.FullName
#         FROM RiderBrandList b
#         JOIN Class1_Wins_Leaderboard s ON b.RiderID = s.RiderID
#         JOIN Rider_List r ON b.RiderID = r.RiderID
#         WHERE b.Brand = 'YAM'
#           AND s.SX_MAINS_Wins >= 1
#
#
# KTM-10+ Premier Class Wins:
#
#         SELECT r.FullName
#         FROM RiderBrandList b
#         JOIN Class1_Wins_Leaderboard s ON b.RiderID = s.RiderID
#         JOIN Rider_List r ON b.RiderID = r.RiderID
#         WHERE b.Brand = 'KTM'
#           AND s.SX_MAINS_Wins >= 10
#
#
# KTM-20+ Premier Class Wins:
#
#         SELECT r.FullName
#         FROM RiderBrandList b
#         JOIN Class1_Wins_Leaderboard s ON b.RiderID = s.RiderID
#         JOIN Rider_List r ON b.RiderID = r.RiderID
#         WHERE b.Brand = 'KTM'
#           AND s.SX_MAINS_Wins >= 20
#
#
# KTM-5+ Premier Class Wins:
#
#         SELECT r.FullName
#         FROM RiderBrandList b
#         JOIN Class1_Wins_Leaderboard s ON b.RiderID = s.RiderID
#         JOIN Rider_List r ON b.RiderID = r.RiderID
#         WHERE b.Brand = 'KTM'
#           AND s.SX_MAINS_Wins >= 5
#
#
# KTM-1+ Premier Class Wins:
#
#         SELECT r.FullName
#         FROM RiderBrandList b
#         JOIN Class1_Wins_Leaderboard s ON b.RiderID = s.RiderID
#         JOIN Rider_List r ON b.RiderID = r.RiderID
#         WHERE b.Brand = 'KTM'
#           AND s.SX_MAINS_Wins >= 1
#
#
# HON-10+ Premier Class Wins:
#
#         SELECT r.FullName
#         FROM RiderBrandList b
#         JOIN Class1_Wins_Leaderboard s ON b.RiderID = s.RiderID
#         JOIN Rider_List r ON b.RiderID = r.RiderID
#         WHERE b.Brand = 'HON'
#           AND s.SX_MAINS_Wins >= 10
#
#
# HON-20+ Premier Class Wins:
#
#         SELECT r.FullName
#         FROM RiderBrandList b
#         JOIN Class1_Wins_Leaderboard s ON b.RiderID = s.RiderID
#         JOIN Rider_List r ON b.RiderID = r.RiderID
#         WHERE b.Brand = 'HON'
#           AND s.SX_MAINS_Wins >= 20
#
#
# HON-5+ Premier Class Wins:
#
#         SELECT r.FullName
#         FROM RiderBrandList b
#         JOIN Class1_Wins_Leaderboard s ON b.RiderID = s.RiderID
#         JOIN Rider_List r ON b.RiderID = r.RiderID
#         WHERE b.Brand = 'HON'
#           AND s.SX_MAINS_Wins >= 5
#
#
# HON-1+ Premier Class Wins:
#
#         SELECT r.FullName
#         FROM RiderBrandList b
#         JOIN Class1_Wins_Leaderboard s ON b.RiderID = s.RiderID
#         JOIN Rider_List r ON b.RiderID = r.RiderID
#         WHERE b.Brand = 'HON'
#           AND s.SX_MAINS_Wins >= 1
#
#
# SUZ-10+ Premier Class Wins:
#
#         SELECT r.FullName
#         FROM RiderBrandList b
#         JOIN Class1_Wins_Leaderboard s ON b.RiderID = s.RiderID
#         JOIN Rider_List r ON b.RiderID = r.RiderID
#         WHERE b.Brand = 'SUZ'
#           AND s.SX_MAINS_Wins >= 10
#
#
# SUZ-20+ Premier Class Wins:
#
#         SELECT r.FullName
#         FROM RiderBrandList b
#         JOIN Class1_Wins_Leaderboard s ON b.RiderID = s.RiderID
#         JOIN Rider_List r ON b.RiderID = r.RiderID
#         WHERE b.Brand = 'SUZ'
#           AND s.SX_MAINS_Wins >= 20
#
#
# SUZ-5+ Premier Class Wins:
#
#         SELECT r.FullName
#         FROM RiderBrandList b
#         JOIN Class1_Wins_Leaderboard s ON b.RiderID = s.RiderID
#         JOIN Rider_List r ON b.RiderID = r.RiderID
#         WHERE b.Brand = 'SUZ'
#           AND s.SX_MAINS_Wins >= 5
#
#
# SUZ-1+ Premier Class Wins:
#
#         SELECT r.FullName
#         FROM RiderBrandList b
#         JOIN Class1_Wins_Leaderboard s ON b.RiderID = s.RiderID
#         JOIN Rider_List r ON b.RiderID = r.RiderID
#         WHERE b.Brand = 'SUZ'
#           AND s.SX_MAINS_Wins >= 1
#
#
# GAS-10+ Premier Class Wins:
#
#         SELECT r.FullName
#         FROM RiderBrandList b
#         JOIN Class1_Wins_Leaderboard s ON b.RiderID = s.RiderID
#         JOIN Rider_List r ON b.RiderID = r.RiderID
#         WHERE b.Brand = 'GAS'
#           AND s.SX_MAINS_Wins >= 10
#
#
# GAS-20+ Premier Class Wins:
#
#         SELECT r.FullName
#         FROM RiderBrandList b
#         JOIN Class1_Wins_Leaderboard s ON b.RiderID = s.RiderID
#         JOIN Rider_List r ON b.RiderID = r.RiderID
#         WHERE b.Brand = 'GAS'
#           AND s.SX_MAINS_Wins >= 20
#
#
# GAS-5+ Premier Class Wins:
#
#         SELECT r.FullName
#         FROM RiderBrandList b
#         JOIN Class1_Wins_Leaderboard s ON b.RiderID = s.RiderID
#         JOIN Rider_List r ON b.RiderID = r.RiderID
#         WHERE b.Brand = 'GAS'
#           AND s.SX_MAINS_Wins >= 5
#
#
# GAS-1+ Premier Class Wins:
#
#         SELECT r.FullName
#         FROM RiderBrandList b
#         JOIN Class1_Wins_Leaderboard s ON b.RiderID = s.RiderID
#         JOIN Rider_List r ON b.RiderID = r.RiderID
#         WHERE b.Brand = 'GAS'
#           AND s.SX_MAINS_Wins >= 1
#
#
# HUS-10+ Premier Class Wins:
#
#         SELECT r.FullName
#         FROM RiderBrandList b
#         JOIN Class1_Wins_Leaderboard s ON b.RiderID = s.RiderID
#         JOIN Rider_List r ON b.RiderID = r.RiderID
#         WHERE b.Brand = 'HUS'
#           AND s.SX_MAINS_Wins >= 10
#
#
# HUS-20+ Premier Class Wins:
#
#         SELECT r.FullName
#         FROM RiderBrandList b
#         JOIN Class1_Wins_Leaderboard s ON b.RiderID = s.RiderID
#         JOIN Rider_List r ON b.RiderID = r.RiderID
#         WHERE b.Brand = 'HUS'
#           AND s.SX_MAINS_Wins >= 20
#
#
# HUS-5+ Premier Class Wins:
#
#         SELECT r.FullName
#         FROM RiderBrandList b
#         JOIN Class1_Wins_Leaderboard s ON b.RiderID = s.RiderID
#         JOIN Rider_List r ON b.RiderID = r.RiderID
#         WHERE b.Brand = 'HUS'
#           AND s.SX_MAINS_Wins >= 5
#
#
# HUS-1+ Premier Class Wins:
#
#         SELECT r.FullName
#         FROM RiderBrandList b
#         JOIN Class1_Wins_Leaderboard s ON b.RiderID = s.RiderID
#         JOIN Rider_List r ON b.RiderID = r.RiderID
#         WHERE b.Brand = 'HUS'
#           AND s.SX_MAINS_Wins >= 1
#
#
# Premier Class SX Champion-United States:
#
#         SELECT r.FullName
#         FROM Champions c
#         JOIN Rider_List r ON c.RiderID = r.RiderID
#         WHERE c.SportID = 1
#           AND c.ClassID = 1
#           AND r.Country = 'United States'
#
#
# Premier Class SX Champion-Australia:
#
#         SELECT r.FullName
#         FROM Champions c
#         JOIN Rider_List r ON c.RiderID = r.RiderID
#         WHERE c.SportID = 1
#           AND c.ClassID = 1
#           AND r.Country = 'Australia'
#
#
# Premier Class SX Champion-France:
#
#         SELECT r.FullName
#         FROM Champions c
#         JOIN Rider_List r ON c.RiderID = r.RiderID
#         WHERE c.SportID = 1
#           AND c.ClassID = 1
#           AND r.Country = 'France'
#
#
# Premier Class SX Champion-South Africa:
#
#         SELECT r.FullName
#         FROM Champions c
#         JOIN Rider_List r ON c.RiderID = r.RiderID
#         WHERE c.SportID = 1
#           AND c.ClassID = 1
#           AND r.Country = 'South Africa'
#
#
# Premier Class SX Champion-10+ Premier Class Wins:
#
#         SELECT r.FullName
#         FROM Champions c
#         JOIN Rider_List r ON c.RiderID = r.RiderID
#         JOIN Class1_Wins_Leaderboard s ON r.RiderID = s.RiderID
#         WHERE c.SportID = 1
#           AND c.ClassID = 1
#           AND s.SX_MAINS_Wins >= 10
#
#
# Premier Class SX Champion-20+ Premier Class Wins:
#
#         SELECT r.FullName
#         FROM Champions c
#         JOIN Rider_List r ON c.RiderID = r.RiderID
#         JOIN Class1_Wins_Leaderboard s ON r.RiderID = s.RiderID
#         WHERE c.SportID = 1
#           AND c.ClassID = 1
#           AND s.SX_MAINS_Wins >= 20
#
#
# Premier Class SX Champion-5+ Premier Class Wins:
#
#         SELECT r.FullName
#         FROM Champions c
#         JOIN Rider_List r ON c.RiderID = r.RiderID
#         JOIN Class1_Wins_Leaderboard s ON r.RiderID = s.RiderID
#         WHERE c.SportID = 1
#           AND c.ClassID = 1
#           AND s.SX_MAINS_Wins >= 5
#
#
# Premier Class SX Champion-1+ Premier Class Wins:
#
#         SELECT r.FullName
#         FROM Champions c
#         JOIN Rider_List r ON c.RiderID = r.RiderID
#         JOIN Class1_Wins_Leaderboard s ON r.RiderID = s.RiderID
#         WHERE c.SportID = 1
#           AND c.ClassID = 1
#           AND s.SX_MAINS_Wins >= 1
#
#
# Lites Class SX Champion-United States:
#
#         SELECT r.FullName
#         FROM Champions c
#         JOIN Rider_List r ON c.RiderID = r.RiderID
#         WHERE c.SportID = 1
#           AND c.ClassID = 2
#           AND r.Country = 'United States'
#
#
# Lites Class SX Champion-Australia:
#
#         SELECT r.FullName
#         FROM Champions c
#         JOIN Rider_List r ON c.RiderID = r.RiderID
#         WHERE c.SportID = 1
#           AND c.ClassID = 2
#           AND r.Country = 'Australia'
#
#
# Lites Class SX Champion-France:
#
#         SELECT r.FullName
#         FROM Champions c
#         JOIN Rider_List r ON c.RiderID = r.RiderID
#         WHERE c.SportID = 1
#           AND c.ClassID = 2
#           AND r.Country = 'France'
#
#
# Lites Class SX Champion-South Africa:
#
#         SELECT r.FullName
#         FROM Champions c
#         JOIN Rider_List r ON c.RiderID = r.RiderID
#         WHERE c.SportID = 1
#           AND c.ClassID = 2
#           AND r.Country = 'South Africa'
#
#
# Lites Class SX Champion-10+ Lites Class Wins:
#
#         SELECT r.FullName
#         FROM Champions c
#         JOIN Rider_List r ON c.RiderID = r.RiderID
#         JOIN Class2_Wins_Leaderboard s ON r.RiderID = s.RiderID
#         WHERE c.SportID = 1
#           AND c.ClassID = 2
#           AND s.SX_MAINS_Wins >= 10
#
#
# Lites Class SX Champion-20+ Lites Class Wins:
#
#         SELECT r.FullName
#         FROM Champions c
#         JOIN Rider_List r ON c.RiderID = r.RiderID
#         JOIN Class2_Wins_Leaderboard s ON r.RiderID = s.RiderID
#         WHERE c.SportID = 1
#           AND c.ClassID = 2
#           AND s.SX_MAINS_Wins >= 20
#
#
# Lites Class SX Champion-5+ Lites Class Wins:
#
#         SELECT r.FullName
#         FROM Champions c
#         JOIN Rider_List r ON c.RiderID = r.RiderID
#         JOIN Class2_Wins_Leaderboard s ON r.RiderID = s.RiderID
#         WHERE c.SportID = 1
#           AND c.ClassID = 2
#           AND s.SX_MAINS_Wins >= 5
#
#
# Lites Class SX Champion-1+ Lites Class Wins:
#
#         SELECT r.FullName
#         FROM Champions c
#         JOIN Rider_List r ON c.RiderID = r.RiderID
#         JOIN Class2_Wins_Leaderboard s ON r.RiderID = s.RiderID
#         WHERE c.SportID = 1
#           AND c.ClassID = 2
#           AND s.SX_MAINS_Wins >= 1
#
#
# 450 MX Champion-United States:
#
#         SELECT r.FullName
#         FROM Champions c
#         JOIN Rider_List r ON c.RiderID = r.RiderID
#         WHERE c.SportID = 2
#           AND c.ClassID = 1
#           AND r.Country = 'United States'
#
#
# 450 MX Champion-Australia:
#
#         SELECT r.FullName
#         FROM Champions c
#         JOIN Rider_List r ON c.RiderID = r.RiderID
#         WHERE c.SportID = 2
#           AND c.ClassID = 1
#           AND r.Country = 'Australia'
#
#
# 450 MX Champion-France:
#
#         SELECT r.FullName
#         FROM Champions c
#         JOIN Rider_List r ON c.RiderID = r.RiderID
#         WHERE c.SportID = 2
#           AND c.ClassID = 1
#           AND r.Country = 'France'
#
#
# 450 MX Champion-South Africa:
#
#         SELECT r.FullName
#         FROM Champions c
#         JOIN Rider_List r ON c.RiderID = r.RiderID
#         WHERE c.SportID = 2
#           AND c.ClassID = 1
#           AND r.Country = 'South Africa'
#
#
# KAW-10+ 450 MX Wins:
#
#         SELECT r.FullName
#         FROM RiderBrandList b
#         JOIN Class1_Wins_Leaderboard s ON b.RiderID = s.RiderID
#         JOIN Rider_List r ON b.RiderID = r.RiderID
#         WHERE b.Brand = 'KAW'
#           AND s.MX_OVERALLS_Wins >= 10
#
#
# KAW-20+ 450 MX Wins:
#
#         SELECT r.FullName
#         FROM RiderBrandList b
#         JOIN Class1_Wins_Leaderboard s ON b.RiderID = s.RiderID
#         JOIN Rider_List r ON b.RiderID = r.RiderID
#         WHERE b.Brand = 'KAW'
#           AND s.MX_OVERALLS_Wins >= 20
#
#
# KAW-5+ 450 MX Wins:
#
#         SELECT r.FullName
#         FROM RiderBrandList b
#         JOIN Class1_Wins_Leaderboard s ON b.RiderID = s.RiderID
#         JOIN Rider_List r ON b.RiderID = r.RiderID
#         WHERE b.Brand = 'KAW'
#           AND s.MX_OVERALLS_Wins >= 5
#
#
# KAW-1+ 450 MX Wins:
#
#         SELECT r.FullName
#         FROM RiderBrandList b
#         JOIN Class1_Wins_Leaderboard s ON b.RiderID = s.RiderID
#         JOIN Rider_List r ON b.RiderID = r.RiderID
#         WHERE b.Brand = 'KAW'
#           AND s.MX_OVERALLS_Wins >= 1
#
#
# YAM-10+ 450 MX Wins:
#
#         SELECT r.FullName
#         FROM RiderBrandList b
#         JOIN Class1_Wins_Leaderboard s ON b.RiderID = s.RiderID
#         JOIN Rider_List r ON b.RiderID = r.RiderID
#         WHERE b.Brand = 'YAM'
#           AND s.MX_OVERALLS_Wins >= 10
#
#
# YAM-20+ 450 MX Wins:
#
#         SELECT r.FullName
#         FROM RiderBrandList b
#         JOIN Class1_Wins_Leaderboard s ON b.RiderID = s.RiderID
#         JOIN Rider_List r ON b.RiderID = r.RiderID
#         WHERE b.Brand = 'YAM'
#           AND s.MX_OVERALLS_Wins >= 20
#
#
# YAM-5+ 450 MX Wins:
#
#         SELECT r.FullName
#         FROM RiderBrandList b
#         JOIN Class1_Wins_Leaderboard s ON b.RiderID = s.RiderID
#         JOIN Rider_List r ON b.RiderID = r.RiderID
#         WHERE b.Brand = 'YAM'
#           AND s.MX_OVERALLS_Wins >= 5
#
#
# YAM-1+ 450 MX Wins:
#
#         SELECT r.FullName
#         FROM RiderBrandList b
#         JOIN Class1_Wins_Leaderboard s ON b.RiderID = s.RiderID
#         JOIN Rider_List r ON b.RiderID = r.RiderID
#         WHERE b.Brand = 'YAM'
#           AND s.MX_OVERALLS_Wins >= 1
#
#
# KTM-10+ 450 MX Wins:
#
#         SELECT r.FullName
#         FROM RiderBrandList b
#         JOIN Class1_Wins_Leaderboard s ON b.RiderID = s.RiderID
#         JOIN Rider_List r ON b.RiderID = r.RiderID
#         WHERE b.Brand = 'KTM'
#           AND s.MX_OVERALLS_Wins >= 10
#
#
# KTM-20+ 450 MX Wins:
#
#         SELECT r.FullName
#         FROM RiderBrandList b
#         JOIN Class1_Wins_Leaderboard s ON b.RiderID = s.RiderID
#         JOIN Rider_List r ON b.RiderID = r.RiderID
#         WHERE b.Brand = 'KTM'
#           AND s.MX_OVERALLS_Wins >= 20
#
#
# KTM-5+ 450 MX Wins:
#
#         SELECT r.FullName
#         FROM RiderBrandList b
#         JOIN Class1_Wins_Leaderboard s ON b.RiderID = s.RiderID
#         JOIN Rider_List r ON b.RiderID = r.RiderID
#         WHERE b.Brand = 'KTM'
#           AND s.MX_OVERALLS_Wins >= 5
#
#
# KTM-1+ 450 MX Wins:
#
#         SELECT r.FullName
#         FROM RiderBrandList b
#         JOIN Class1_Wins_Leaderboard s ON b.RiderID = s.RiderID
#         JOIN Rider_List r ON b.RiderID = r.RiderID
#         WHERE b.Brand = 'KTM'
#           AND s.MX_OVERALLS_Wins >= 1
#
#
# HON-10+ 450 MX Wins:
#
#         SELECT r.FullName
#         FROM RiderBrandList b
#         JOIN Class1_Wins_Leaderboard s ON b.RiderID = s.RiderID
#         JOIN Rider_List r ON b.RiderID = r.RiderID
#         WHERE b.Brand = 'HON'
#           AND s.MX_OVERALLS_Wins >= 10
#
#
# HON-20+ 450 MX Wins:
#
#         SELECT r.FullName
#         FROM RiderBrandList b
#         JOIN Class1_Wins_Leaderboard s ON b.RiderID = s.RiderID
#         JOIN Rider_List r ON b.RiderID = r.RiderID
#         WHERE b.Brand = 'HON'
#           AND s.MX_OVERALLS_Wins >= 20
#
#
# HON-5+ 450 MX Wins:
#
#         SELECT r.FullName
#         FROM RiderBrandList b
#         JOIN Class1_Wins_Leaderboard s ON b.RiderID = s.RiderID
#         JOIN Rider_List r ON b.RiderID = r.RiderID
#         WHERE b.Brand = 'HON'
#           AND s.MX_OVERALLS_Wins >= 5
#
#
# HON-1+ 450 MX Wins:
#
#         SELECT r.FullName
#         FROM RiderBrandList b
#         JOIN Class1_Wins_Leaderboard s ON b.RiderID = s.RiderID
#         JOIN Rider_List r ON b.RiderID = r.RiderID
#         WHERE b.Brand = 'HON'
#           AND s.MX_OVERALLS_Wins >= 1
#
#
# SUZ-10+ 450 MX Wins:
#
#         SELECT r.FullName
#         FROM RiderBrandList b
#         JOIN Class1_Wins_Leaderboard s ON b.RiderID = s.RiderID
#         JOIN Rider_List r ON b.RiderID = r.RiderID
#         WHERE b.Brand = 'SUZ'
#           AND s.MX_OVERALLS_Wins >= 10
#
#
# SUZ-20+ 450 MX Wins:
#
#         SELECT r.FullName
#         FROM RiderBrandList b
#         JOIN Class1_Wins_Leaderboard s ON b.RiderID = s.RiderID
#         JOIN Rider_List r ON b.RiderID = r.RiderID
#         WHERE b.Brand = 'SUZ'
#           AND s.MX_OVERALLS_Wins >= 20
#
#
# SUZ-5+ 450 MX Wins:
#
#         SELECT r.FullName
#         FROM RiderBrandList b
#         JOIN Class1_Wins_Leaderboard s ON b.RiderID = s.RiderID
#         JOIN Rider_List r ON b.RiderID = r.RiderID
#         WHERE b.Brand = 'SUZ'
#           AND s.MX_OVERALLS_Wins >= 5
#
#
# SUZ-1+ 450 MX Wins:
#
#         SELECT r.FullName
#         FROM RiderBrandList b
#         JOIN Class1_Wins_Leaderboard s ON b.RiderID = s.RiderID
#         JOIN Rider_List r ON b.RiderID = r.RiderID
#         WHERE b.Brand = 'SUZ'
#           AND s.MX_OVERALLS_Wins >= 1
#
#
# GAS-10+ 450 MX Wins:
#
#         SELECT r.FullName
#         FROM RiderBrandList b
#         JOIN Class1_Wins_Leaderboard s ON b.RiderID = s.RiderID
#         JOIN Rider_List r ON b.RiderID = r.RiderID
#         WHERE b.Brand = 'GAS'
#           AND s.MX_OVERALLS_Wins >= 10
#
#
# GAS-20+ 450 MX Wins:
#
#         SELECT r.FullName
#         FROM RiderBrandList b
#         JOIN Class1_Wins_Leaderboard s ON b.RiderID = s.RiderID
#         JOIN Rider_List r ON b.RiderID = r.RiderID
#         WHERE b.Brand = 'GAS'
#           AND s.MX_OVERALLS_Wins >= 20
#
#
# GAS-5+ 450 MX Wins:
#
#         SELECT r.FullName
#         FROM RiderBrandList b
#         JOIN Class1_Wins_Leaderboard s ON b.RiderID = s.RiderID
#         JOIN Rider_List r ON b.RiderID = r.RiderID
#         WHERE b.Brand = 'GAS'
#           AND s.MX_OVERALLS_Wins >= 5
#
#
# GAS-1+ 450 MX Wins:
#
#         SELECT r.FullName
#         FROM RiderBrandList b
#         JOIN Class1_Wins_Leaderboard s ON b.RiderID = s.RiderID
#         JOIN Rider_List r ON b.RiderID = r.RiderID
#         WHERE b.Brand = 'GAS'
#           AND s.MX_OVERALLS_Wins >= 1
#
#
# HUS-10+ 450 MX Wins:
#
#         SELECT r.FullName
#         FROM RiderBrandList b
#         JOIN Class1_Wins_Leaderboard s ON b.RiderID = s.RiderID
#         JOIN Rider_List r ON b.RiderID = r.RiderID
#         WHERE b.Brand = 'HUS'
#           AND s.MX_OVERALLS_Wins >= 10
#
#
# HUS-20+ 450 MX Wins:
#
#         SELECT r.FullName
#         FROM RiderBrandList b
#         JOIN Class1_Wins_Leaderboard s ON b.RiderID = s.RiderID
#         JOIN Rider_List r ON b.RiderID = r.RiderID
#         WHERE b.Brand = 'HUS'
#           AND s.MX_OVERALLS_Wins >= 20
#
#
# HUS-5+ 450 MX Wins:
#
#         SELECT r.FullName
#         FROM RiderBrandList b
#         JOIN Class1_Wins_Leaderboard s ON b.RiderID = s.RiderID
#         JOIN Rider_List r ON b.RiderID = r.RiderID
#         WHERE b.Brand = 'HUS'
#           AND s.MX_OVERALLS_Wins >= 5
#
#
# HUS-1+ 450 MX Wins:
#
#         SELECT r.FullName
#         FROM RiderBrandList b
#         JOIN Class1_Wins_Leaderboard s ON b.RiderID = s.RiderID
#         JOIN Rider_List r ON b.RiderID = r.RiderID
#         WHERE b.Brand = 'HUS'
#           AND s.MX_OVERALLS_Wins >= 1
#
#
# KAW-10+ 250 MX Wins:
#
#         SELECT r.FullName
#         FROM RiderBrandList b
#         JOIN Class2_Wins_Leaderboard s ON b.RiderID = s.RiderID
#         JOIN Rider_List r ON b.RiderID = r.RiderID
#         WHERE b.Brand = 'KAW'
#           AND s.MX_OVERALLS_Wins >= 10
#
#
# KAW-20+ 250 MX Wins:
#
#         SELECT r.FullName
#         FROM RiderBrandList b
#         JOIN Class2_Wins_Leaderboard s ON b.RiderID = s.RiderID
#         JOIN Rider_List r ON b.RiderID = r.RiderID
#         WHERE b.Brand = 'KAW'
#           AND s.MX_OVERALLS_Wins >= 20
#
#
# KAW-5+ 250 MX Wins:
#
#         SELECT r.FullName
#         FROM RiderBrandList b
#         JOIN Class2_Wins_Leaderboard s ON b.RiderID = s.RiderID
#         JOIN Rider_List r ON b.RiderID = r.RiderID
#         WHERE b.Brand = 'KAW'
#           AND s.MX_OVERALLS_Wins >= 5
#
#
# KAW-1+ 250 MX Wins:
#
#         SELECT r.FullName
#         FROM RiderBrandList b
#         JOIN Class2_Wins_Leaderboard s ON b.RiderID = s.RiderID
#         JOIN Rider_List r ON b.RiderID = r.RiderID
#         WHERE b.Brand = 'KAW'
#           AND s.MX_OVERALLS_Wins >= 1
#
#
# YAM-10+ 250 MX Wins:
#
#         SELECT r.FullName
#         FROM RiderBrandList b
#         JOIN Class2_Wins_Leaderboard s ON b.RiderID = s.RiderID
#         JOIN Rider_List r ON b.RiderID = r.RiderID
#         WHERE b.Brand = 'YAM'
#           AND s.MX_OVERALLS_Wins >= 10
#
#
# YAM-20+ 250 MX Wins:
#
#         SELECT r.FullName
#         FROM RiderBrandList b
#         JOIN Class2_Wins_Leaderboard s ON b.RiderID = s.RiderID
#         JOIN Rider_List r ON b.RiderID = r.RiderID
#         WHERE b.Brand = 'YAM'
#           AND s.MX_OVERALLS_Wins >= 20
#
#
# YAM-5+ 250 MX Wins:
#
#         SELECT r.FullName
#         FROM RiderBrandList b
#         JOIN Class2_Wins_Leaderboard s ON b.RiderID = s.RiderID
#         JOIN Rider_List r ON b.RiderID = r.RiderID
#         WHERE b.Brand = 'YAM'
#           AND s.MX_OVERALLS_Wins >= 5
#
#
# YAM-1+ 250 MX Wins:
#
#         SELECT r.FullName
#         FROM RiderBrandList b
#         JOIN Class2_Wins_Leaderboard s ON b.RiderID = s.RiderID
#         JOIN Rider_List r ON b.RiderID = r.RiderID
#         WHERE b.Brand = 'YAM'
#           AND s.MX_OVERALLS_Wins >= 1
#
#
# KTM-10+ 250 MX Wins:
#
#         SELECT r.FullName
#         FROM RiderBrandList b
#         JOIN Class2_Wins_Leaderboard s ON b.RiderID = s.RiderID
#         JOIN Rider_List r ON b.RiderID = r.RiderID
#         WHERE b.Brand = 'KTM'
#           AND s.MX_OVERALLS_Wins >= 10
#
#
# KTM-20+ 250 MX Wins:
#
#         SELECT r.FullName
#         FROM RiderBrandList b
#         JOIN Class2_Wins_Leaderboard s ON b.RiderID = s.RiderID
#         JOIN Rider_List r ON b.RiderID = r.RiderID
#         WHERE b.Brand = 'KTM'
#           AND s.MX_OVERALLS_Wins >= 20
#
#
# KTM-5+ 250 MX Wins:
#
#         SELECT r.FullName
#         FROM RiderBrandList b
#         JOIN Class2_Wins_Leaderboard s ON b.RiderID = s.RiderID
#         JOIN Rider_List r ON b.RiderID = r.RiderID
#         WHERE b.Brand = 'KTM'
#           AND s.MX_OVERALLS_Wins >= 5
#
#
# KTM-1+ 250 MX Wins:
#
#         SELECT r.FullName
#         FROM RiderBrandList b
#         JOIN Class2_Wins_Leaderboard s ON b.RiderID = s.RiderID
#         JOIN Rider_List r ON b.RiderID = r.RiderID
#         WHERE b.Brand = 'KTM'
#           AND s.MX_OVERALLS_Wins >= 1
#
#
# HON-10+ 250 MX Wins:
#
#         SELECT r.FullName
#         FROM RiderBrandList b
#         JOIN Class2_Wins_Leaderboard s ON b.RiderID = s.RiderID
#         JOIN Rider_List r ON b.RiderID = r.RiderID
#         WHERE b.Brand = 'HON'
#           AND s.MX_OVERALLS_Wins >= 10
#
#
# HON-20+ 250 MX Wins:
#
#         SELECT r.FullName
#         FROM RiderBrandList b
#         JOIN Class2_Wins_Leaderboard s ON b.RiderID = s.RiderID
#         JOIN Rider_List r ON b.RiderID = r.RiderID
#         WHERE b.Brand = 'HON'
#           AND s.MX_OVERALLS_Wins >= 20
#
#
# HON-5+ 250 MX Wins:
#
#         SELECT r.FullName
#         FROM RiderBrandList b
#         JOIN Class2_Wins_Leaderboard s ON b.RiderID = s.RiderID
#         JOIN Rider_List r ON b.RiderID = r.RiderID
#         WHERE b.Brand = 'HON'
#           AND s.MX_OVERALLS_Wins >= 5
#
#
# HON-1+ 250 MX Wins:
#
#         SELECT r.FullName
#         FROM RiderBrandList b
#         JOIN Class2_Wins_Leaderboard s ON b.RiderID = s.RiderID
#         JOIN Rider_List r ON b.RiderID = r.RiderID
#         WHERE b.Brand = 'HON'
#           AND s.MX_OVERALLS_Wins >= 1
#
#
# SUZ-10+ 250 MX Wins:
#
#         SELECT r.FullName
#         FROM RiderBrandList b
#         JOIN Class2_Wins_Leaderboard s ON b.RiderID = s.RiderID
#         JOIN Rider_List r ON b.RiderID = r.RiderID
#         WHERE b.Brand = 'SUZ'
#           AND s.MX_OVERALLS_Wins >= 10
#
#
# SUZ-20+ 250 MX Wins:
#
#         SELECT r.FullName
#         FROM RiderBrandList b
#         JOIN Class2_Wins_Leaderboard s ON b.RiderID = s.RiderID
#         JOIN Rider_List r ON b.RiderID = r.RiderID
#         WHERE b.Brand = 'SUZ'
#           AND s.MX_OVERALLS_Wins >= 20
#
#
# SUZ-5+ 250 MX Wins:
#
#         SELECT r.FullName
#         FROM RiderBrandList b
#         JOIN Class2_Wins_Leaderboard s ON b.RiderID = s.RiderID
#         JOIN Rider_List r ON b.RiderID = r.RiderID
#         WHERE b.Brand = 'SUZ'
#           AND s.MX_OVERALLS_Wins >= 5
#
#
# SUZ-1+ 250 MX Wins:
#
#         SELECT r.FullName
#         FROM RiderBrandList b
#         JOIN Class2_Wins_Leaderboard s ON b.RiderID = s.RiderID
#         JOIN Rider_List r ON b.RiderID = r.RiderID
#         WHERE b.Brand = 'SUZ'
#           AND s.MX_OVERALLS_Wins >= 1
#
#
# GAS-10+ 250 MX Wins:
#
#         SELECT r.FullName
#         FROM RiderBrandList b
#         JOIN Class2_Wins_Leaderboard s ON b.RiderID = s.RiderID
#         JOIN Rider_List r ON b.RiderID = r.RiderID
#         WHERE b.Brand = 'GAS'
#           AND s.MX_OVERALLS_Wins >= 10
#
#
# GAS-20+ 250 MX Wins:
#
#         SELECT r.FullName
#         FROM RiderBrandList b
#         JOIN Class2_Wins_Leaderboard s ON b.RiderID = s.RiderID
#         JOIN Rider_List r ON b.RiderID = r.RiderID
#         WHERE b.Brand = 'GAS'
#           AND s.MX_OVERALLS_Wins >= 20
#
#
# GAS-5+ 250 MX Wins:
#
#         SELECT r.FullName
#         FROM RiderBrandList b
#         JOIN Class2_Wins_Leaderboard s ON b.RiderID = s.RiderID
#         JOIN Rider_List r ON b.RiderID = r.RiderID
#         WHERE b.Brand = 'GAS'
#           AND s.MX_OVERALLS_Wins >= 5
#
#
# GAS-1+ 250 MX Wins:
#
#         SELECT r.FullName
#         FROM RiderBrandList b
#         JOIN Class2_Wins_Leaderboard s ON b.RiderID = s.RiderID
#         JOIN Rider_List r ON b.RiderID = r.RiderID
#         WHERE b.Brand = 'GAS'
#           AND s.MX_OVERALLS_Wins >= 1
#
#
# HUS-10+ 250 MX Wins:
#
#         SELECT r.FullName
#         FROM RiderBrandList b
#         JOIN Class2_Wins_Leaderboard s ON b.RiderID = s.RiderID
#         JOIN Rider_List r ON b.RiderID = r.RiderID
#         WHERE b.Brand = 'HUS'
#           AND s.MX_OVERALLS_Wins >= 10
#
#
# HUS-20+ 250 MX Wins:
#
#         SELECT r.FullName
#         FROM RiderBrandList b
#         JOIN Class2_Wins_Leaderboard s ON b.RiderID = s.RiderID
#         JOIN Rider_List r ON b.RiderID = r.RiderID
#         WHERE b.Brand = 'HUS'
#           AND s.MX_OVERALLS_Wins >= 20
#
#
# HUS-5+ 250 MX Wins:
#
#         SELECT r.FullName
#         FROM RiderBrandList b
#         JOIN Class2_Wins_Leaderboard s ON b.RiderID = s.RiderID
#         JOIN Rider_List r ON b.RiderID = r.RiderID
#         WHERE b.Brand = 'HUS'
#           AND s.MX_OVERALLS_Wins >= 5
#
#
# HUS-1+ 250 MX Wins:
#
#         SELECT r.FullName
#         FROM RiderBrandList b
#         JOIN Class2_Wins_Leaderboard s ON b.RiderID = s.RiderID
#         JOIN Rider_List r ON b.RiderID = r.RiderID
#         WHERE b.Brand = 'HUS'
#           AND s.MX_OVERALLS_Wins >= 1

# %%
import json

def save_queries_to_json(queries, filename='all_queries.json'):
    # Save the dictionary of queries to a JSON file
    with open(filename, 'w') as file:
        json.dump(queries, file, indent=4)

# Example usage
save_queries_to_json(all_queries)
print("Queries saved to all_queries.json")
# Out:
# Queries saved to all_queries.json

# %%
import pickle

def save_queries_to_pickle(queries, filename='all_queries.pkl'):
    # Save the dictionary of queries to a pickle file
    with open(filename, 'wb') as file:
        pickle.dump(queries, file)

# Example usage
save_queries_to_pickle(all_queries)
print("Queries saved to all_queries.pkl")
# Out:
# Queries saved to all_queries.pkl

# %%
def load_queries_from_pickle(filename='all_queries.pkl'):
    # Load the dictionary of queries from a pickle file
    with open(filename, 'rb') as file:
        return pickle.load(file)

# Example usage
all_queries = load_queries_from_pickle()
print("Queries loaded from all_queries.pkl")
# Out:
# Queries loaded from all_queries.pkl

# %%
import random
import pyodbc

def select_random_criteria():
    selected_keys = random.sample(list(all_queries.keys()), 9)
    row_criteria = list({key.split('-')[0] for key in selected_keys[:3]})
    column_criteria = list({key.split('-')[1] for key in selected_keys[3:6]})
    
    while len(row_criteria) < 3 or len(column_criteria) < 3:
        selected_keys = random.sample(list(all_queries.keys()), 9)
        row_criteria = list({key.split('-')[0] for key in selected_keys[:3]})
        column_criteria = list({key.split('-')[1] for key in selected_keys[3:6]})
    
    return row_criteria, column_criteria

def fetch_results_for_cell(query, connection_string):
    try:
        conn = pyodbc.connect(connection_string)
        cursor = conn.cursor()
        cursor.execute(query)
        results = set(row[0].strip().lower() for row in cursor.fetchall())
        conn.close()
        return results
    except Exception as e:
        print(f"Error fetching data for query: {query}\nError: {e}")
        return set()

def generate_fixed_grid(row_criteria, column_criteria, connection_string):
    grid = {}
    for row in row_criteria:
        for column in column_criteria:
            query_key = f"{row}-{column}"
            if query_key in all_queries:
                query = all_queries[query_key]
                results = fetch_results_for_cell(query, connection_string)
                grid[(row, column)] = results
            else:
                grid[(row, column)] = set()
    return grid

def validate_grid(grid):
    """
    Validate if the grid can be solved without creating deadlock situations.
    Checks for singleton and limited-option cells to ensure their unique answers aren't used elsewhere.
    """
    # Identify singleton cells (cells with only one rider).
    singleton_cells = {
        cell: next(iter(riders)) for cell, riders in grid.items() if len(riders) == 1
    }

    # Identify limited-option cells (cells with 2 or 3 riders).
    limited_option_cells = {
        cell: riders for cell, riders in grid.items() if 1 < len(riders) <= 5
    }

    # Track cells where each rider appears.
    rider_appearances = {}
    for (row, column), riders in grid.items():
        for rider in riders:
            rider_appearances.setdefault(rider, []).append((row, column))

    # Ensure that singletons don't overlap with other potential uses.
    for cell, singleton_rider in singleton_cells.items():
        if len(rider_appearances[singleton_rider]) > 1:
            return False  # This rider appears in multiple cells, so it's not a valid singleton.

    # Ensure limited-option cells don't get blocked by choices in other cells.
    for cell, limited_riders in limited_option_cells.items():
        for rider in limited_riders:
            # If a limited rider appears in other cells, ensure that the other cells have enough options left.
            if len(rider_appearances[rider]) > 1:
                # Calculate the total available options for each cell where the rider appears.
                total_options = sum(len(grid[other_cell]) for other_cell in rider_appearances[rider])
                if total_options <= len(rider_appearances[rider]):
                    return False  # Not enough flexibility to accommodate this rider in other cells.

    # If singleton and limited-option checks pass, proceed to backtracking validation.
    def is_grid_solvable(used_riders, remaining_cells):
        remaining_cells = sorted(remaining_cells, key=lambda x: len(x[1]))
        if not remaining_cells:
            return True

        (row, column), correct_riders = remaining_cells[0]
        available_riders = correct_riders - used_riders

        if not available_riders:
            return False

        for rider in available_riders:
            used_riders.add(rider)
            new_remaining_cells = [
                ((r, c), options - {rider}) for (r, c), options in remaining_cells[1:]
            ]
            if is_grid_solvable(used_riders, new_remaining_cells):
                return True
            used_riders.remove(rider)

        return False

    remaining_cells = list(grid.items())
    used_riders = set()
    return is_grid_solvable(used_riders, remaining_cells)

def display_grid_structure(row_criteria, column_criteria):
    print("\nGame Grid Structure:")
    print(f"{'':<30}", end="")
    for col in column_criteria:
        print(f"{col:<30}", end="")
    print("\n" + "-" * (30 * (len(column_criteria) + 1)))

    for row in row_criteria:
        print(f"{row:<30}", end="")
        for col in column_criteria:
            print(f"{row} - {col:<30}", end="")
        print()
    print("\n")

def play_game(grid, row_criteria, column_criteria):
    display_grid_structure(row_criteria, column_criteria)
    print("\nWelcome to the Rider Guessing Game!")
    print("You need to guess riders that match the given criteria for each grid cell.")
    print("Remember, each rider can only be used once!\n")

    used_riders = set()
    correct_guesses = 0
    total_cells = len(grid)
    guessed_cells = set()

    for (row, column), correct_riders in grid.items():
        if (row, column) not in guessed_cells:
            while True:
                print(f"\nCategory: {row} - {column}")
                user_input = input("Your guess (or type 'skip' to skip this cell): ").strip().lower()

                if user_input == 'skip':
                    print("You chose to skip this cell. Moving on to the next one.\n")
                    break

                if user_input in used_riders:
                    print(f"{user_input.title()} has already been used. Try again.")
                    continue

                if user_input in correct_riders:
                    print(f"Correct! {user_input.title()} matches the criteria for {row} - {column}.\n")
                    used_riders.add(user_input)
                    correct_guesses += 1
                    guessed_cells.add((row, column))
                    break
                else:
                    print(f"Incorrect guess for {row} - {column}. Try again or type 'skip' to move on.\n")

    print("\nGame Over!")
    print(f"You made {correct_guesses} correct guesses out of {total_cells} cells.")
    print(f"Your final score is {correct_guesses}/{total_cells}.")

    if correct_guesses == total_cells:
        print("Congratulations! You completed the entire grid!")
    else:
        print("Better luck next time! Here's a summary of the remaining cells:\n")
        for (row, column), correct_riders in grid.items():
            if (row, column) not in guessed_cells:
                print(f"{row} - {column}: Possible answers were {', '.join(rider.title() for rider in correct_riders)}")

# Main logic to keep trying until a valid grid is generated
connection_string = 'DRIVER={ODBC Driver 17 for SQL Server};SERVER=DESKTOP-JHKSS4K\\MXDATABASE;DATABASE=SX-MX-DATABASE;Trusted_Connection=yes;'
max_attempts = 10
attempt = 0

while attempt < max_attempts:
    attempt += 1
    print(f"\nAttempt {attempt}: Generating and validating a new grid...")
    row_criteria, column_criteria = select_random_criteria()
    grid = generate_fixed_grid(row_criteria, column_criteria, connection_string)

    if validate_grid(grid):
        print("Generated grid is valid and playable.")
        print("Grid Criteria:")
        print(f"Rows: {row_criteria}")
        print(f"Columns: {column_criteria}")
        for (row, column), riders in grid.items():
            print(f"({row}, {column}): {riders}")
        play_game(grid, row_criteria, column_criteria)
        break
    else:
        print("Generated grid is not playable. Trying again with different categories.")

if attempt == max_attempts:
    print("Failed to generate a valid grid after multiple attempts. Please check the criteria and database.")
# Out:
# Attempt 1: Generating and validating a new grid...
# Generated grid is not playable. Trying again with different categories.
#
# Attempt 2: Generating and validating a new grid...
# Generated grid is valid and playable.
# Grid Criteria:
# Rows: ['HUS', 'HON', 'YAM']
# Columns: ['United States', '10+ 450 MX Wins', '1+ 450 MX Wins']
# (HUS, United States): {'cade clason', 'bruce dengler', 'lane shaw', 'kyle hameister', 'r.j. hampshire', 'johnnie buller', 'joey deneen', 'steve hackney', 'ben lamay', 'tj albright', 'zach bell', 'dan turner', 'harris huizenga', 'ricky renner', 'bill glore', 'jesse flock', 'carson tickle', 'tristan titus', 'jeffrey walker', 'shane mcelrath', 'will stockland', 'ryan quinn', 'gary pustelak', 'scott paul', 'david boles', 'maxwell mayer', 
thompson', 'ryan mills', 'lee mcilvaine', 'dylan lord', 'zachary peddie', 'todd bannister', 'travis baker', 'jimmy wilson', 'sean dukes', 'john pauk', 'dan ulven', 'ron sun', 'rodney gabriel', 'danny smith', 'jared lesher', 'danny laporte', 'michael picone', 'mark pledger', 'brian hulsey', 'bob westerman', 'duane dreyer', 'vince devane', "ricky o'brien", 'mike fisher', 'joey olson', 'justin brayton', 'tyler duncan', 'grayson hart', 'joe lafalce', 'dennis jonan', 'mike treadwell', 'chris d hunter', 'clifford c cook', 'michael s koch', 'andy c mathieu', 'matthew vonlinger', 'ty morrow', 'christopher akaydin', 'dylan merriam', 'sean lipanovich', 'seamus sullivan', 'tanner sawyer', 'brad nauditt', 'rashidi kerrison', 'blake lilly', 'ronald madole', 'scott sheak', 'branden brill', 'beni williams jr.', 'andreas hultman', 'matthew klann', 'bobby fitch', 'roy c horton jr', 'rex staten', 'ron turner', 'sean hamblin', 'patrick barton', 'deegan hepp', 'ron jones', 'trampas parker', 'benny bloss', 'keith tucker', 'drew craven', 'ted brady', 'mark kane', 'cheyenne harmon', 'michael crane', 'derek l mahoney', 'mike shoemaker', 'donald bliss', 'jon d logan', "johnny o'mara", 'john reinholt', 'randy valade', 'ivan tedesco', 'ty wallace', 'derek fratz-orr', 'hunter yoder', 'damon bradshaw', 'jeff alessi', 'micky dymond', 'carter gordon', 'don bisceglia', 'jed green', 'robert buffaloe', 'ryan duff', 'gary semics', 'dalton harris', 'kris keefer', 'jeff northrop', 'ronnie orres', 'kyle j mace', 'corey burnett', 'seth ciccarelli', 'chris d sprenkel', 'eric mckenna', 'jimmy h lamastus', 'andrew l bakken', 'richard sands', 'tyler custer', 'clint latham', 'dylan marsh', 'nathan j miller', 'matt j karlsen', 'hans neel', 'eric j mccrummen', 'heath voss', 'chris canning' ...
# (HON, 10+ 450 MX Wins): {'jeff stanton', 'kevin windham', 'gary jones', 'ken roczen', 'jeremy mcgrath', 'jett lawrence', 'ricky carmichael', 'rick johnson', 'mike larocco', 'eli tomac', 'kent howerton', 'bob hannah', 'chad reed', 'mike kiedrowski', 'chase sexton'}
# (HON, 1+ 450 MX Wins): {'jeff stanton', 'jean michel bayle', 'ron lechien', 'damon bradshaw', 'dylan ferrandis', 'david bailey', 'rick johnson', 'justin bogle', 'kent howerton', 'donnie hansen', 'chad reed', 'mike kiedrowski', 'marty smith', 'kevin windham', 'jim pomeroy', 'ken roczen', 'marty tripes', 'tim ferry', 'mike larocco', 'alan king', 'david vuillemin', 'brett metcalfe', 'john dowd', 'josh grant', 'billy grossi', 'gary jones', 'zach osborne', 'jett lawrence', 'justin barcia', 'ricky carmichael', 'bob hannah', 'trey canard', "johnny o'mara", 'mickael pichon', 'pierre karsmakers', 'steve wise', 'jimmy button', 'broc glover', 'tommy hahn', 'jeremy mcgrath', 'sebastien tortelli', 'mike alessi', 'ivan tedesco', 'ken zahrt', 'ezra lusk', 'kenny keylon', 'eli tomac', 'doug henry', 'jimmy ellis', 'billy liles', 'chase sexton'}
chris young', 'hunter sayles', 'michael s koch', 'ethan chesnut', 'austin roberts', 'dylan merriam', 'sean lipanovich', 'jeff little', 'gage hulsey', 'kyle farren', 'daniel n pepoon jr', 'scott sheak', 'ty newcome', 'branden brill', 'beni williams jr.', 'christopher cornish', 'matthew klann', 'chad sanner', 'pierce knight', 'nicholas tomasunas', 'bobby fitch', 'rex staten', 'ron turner', 'james edwards', 'sean hamblin', 'steven w onisko', 'kirk dillon', 'nicholas maret', 'keegan rowley', 'johji ohkawara', 'benny bloss', 'charles mccall', 'keith tucker', 'cheyenne harmon', 'chappy blose', 'timothy hollenbeck', 'kirk pierce', 'francis daley', 'mike shoemaker', 'dustin jensen', 'david jordan', 'mark gregson', 'jeff vidic', 'john reinholt', 'randy valade', 'ivan tedesco', 'ty wallace', 'david lodermeier', 'damon bradshaw', 'damian buccieri', 'jeff alessi', 'micky dymond', 'luke bierek', 'shane kehoe', 'brett boski', 'bryce shelly', 'shawn waring', 'phil lawrence', 'robert buffaloe ...
# (YAM, 10+ 450 MX Wins): {'jeff stanton', 'kevin windham', 'gary jones', 'jeff emig', 'jeremy mcgrath', 'jeff ward', 'rick johnson', 'mike larocco', 'eli tomac', 'bob hannah', 'chad reed', 'james stewart'}
# (YAM, 1+ 450 MX Wins): {'jeff stanton', 'grant langston', 'jeff emig', 'ron lechien', 'damon bradshaw', 'dylan ferrandis', 'tim hart', 'david bailey', 'rick johnson', 'jim weinert', 'chad reed', 'kevin windham', 'sonny defeo', 'marty tripes', 'jeff ward', 'tim ferry', 'mike larocco', 'david vuillemin', 'brett metcalfe', 'john dowd', 'matthew goerke', 'josh grant', 'gary jones', 'zach osborne', 'justin barcia', 'cooper webb', 'bob hannah', 'pierre karsmakers', 'jimmy button', 'broc glover', 'tommy hahn', 'jeremy mcgrath', 'ivan tedesco', 'ken zahrt', 'jeff matiasevich', 'ezra lusk', 'kenny keylon', 'eli tomac', 'doug henry', 'jimmy ellis', 'james stewart'}
#
# Game Grid Structure:
#                               United States                 10+ 450 MX Wins               1+ 450 MX Wins
# ------------------------------------------------------------------------------------------------------------------------
# HUS                           HUS - United States                 HUS - 10+ 450 MX Wins               HUS - 1+ 450 MX Wins
# HON                           HON - United States                 HON - 10+ 450 MX Wins               HON - 1+ 450 MX Wins
# YAM                           YAM - United States                 YAM - 10+ 450 MX Wins               YAM - 1+ 450 MX Wins
#
#
#
# Welcome to the Rider Guessing Game!
# You need to guess riders that match the given criteria for each grid cell.
# Remember, each rider can only be used once!
#
#
# Category: HUS - United States
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16020/1472135165.py in <module>
#     180         for (row, column), riders in grid.items():
#     181             print(f"({row}, {column}): {riders}")
# --> 182         play_game(grid, row_criteria, column_criteria)
#     183         break
#     184     else:
#
# ~\AppData\Local\Temp/ipykernel_16020/1472135165.py in play_game(grid, row_criteria, column_criteria)
#     131             while True:
#     132                 print(f"\nCategory: {row} - {column}")
# --> 133                 user_input = input("Your guess (or type 'skip' to skip this cell): ").strip().lower()
#     134
#     135                 if user_input == 'skip':
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#    1004                 "raw_input was called, but this frontend does not support input requests."
#    1005             )
# -> 1006         return self._input_request(
#    1007             str(prompt),
#    1008             self._parent_ident["shell"],
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1049             except KeyboardInterrupt:
#    1050                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1051                 raise KeyboardInterrupt("Interrupted by user") from None
#    1052             except Exception:
#    1053                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
